# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

# %%
df= pd.read_csv("cleaned.csv")

# %%
df
# Out:
#                                 order_id order_purchase_timestamp   price  \
# 0       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 1       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 2       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 3       53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37  118.70
# 4       47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49  159.90
# ...                                  ...                      ...     ...
# 107212  9c5dedf39a927c1b2549525ed64a053c      2017-03-09 09:54:05   72.00
# 107213  63943bddc261676b46f01ca7ac2f7bd8      2018-02-06 12:58:58  174.90
# 107214  83c1379a015df1e13d02aae0204711ab      2017-08-27 14:46:43  205.99
# 107215  11c177c8e97725db2631073c19f07b62      2018-01-08 21:28:27  179.99
# 107216  66dea50a8b16d9b4dee7af250b4be1a5      2018-03-08 20:57:30   68.50
#
#         freight_value  payment_value payment_type  customer_state  \
# ...

# %%
# Step 1: Count how many times each payment type appears
payment_counts = df['payment_type'].value_counts()

# Step 2: Plot a pie chart from those counts
plt.pie(
    payment_counts,                      # The values (how big each slice is)
    labels=payment_counts.index,         # The names for each slice
    autopct='%1.1f%%',                   # Show percentages with 1 decimal place
    startangle=140                       # Rotate it a bit for visual balance
)

plt.title('Payment Type Distribution')
#plt.axis('equal')  # This keeps the pie circle-shaped (not an oval)
plt.legend()
plt.show()

# %%
reviews=df['review_category'].value_counts()
plt.bar(reviews.index,reviews)
plt.title("review distribution")
# Out:
# Text(0.5, 1.0, 'review distribution')

# %%
df['order_purchase_timestamp']=pd.to_datetime(df['order_purchase_timestamp'])

# %%
df
# Out:
#                                 order_id order_purchase_timestamp   price  \
# 0       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 1       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 2       e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33   29.99
# 3       53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37  118.70
# 4       47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49  159.90
# ...                                  ...                      ...     ...
# 107212  9c5dedf39a927c1b2549525ed64a053c      2017-03-09 09:54:05   72.00
# 107213  63943bddc261676b46f01ca7ac2f7bd8      2018-02-06 12:58:58  174.90
# 107214  83c1379a015df1e13d02aae0204711ab      2017-08-27 14:46:43  205.99
# 107215  11c177c8e97725db2631073c19f07b62      2018-01-08 21:28:27  179.99
# 107216  66dea50a8b16d9b4dee7af250b4be1a5      2018-03-08 20:57:30   68.50
#
#         freight_value  payment_value payment_type  customer_state  \
# ...

# %%
month_count=df['months'].value_counts()

# %%
month_order = ["January", "February", "March", "April", "May", "June",
               "July", "August", "September", "October", "November", "December"]

# %%
month_count.index = month_count.index.str.strip().str.title()

# %%
month_count = month_count.loc[month_order]

# %%
plt.plot(month_count.index,month_count.values)

# %%
Customer_state=df['customer_state'].value_counts()
Customer_state=Customer_state.head(10)

# %%
Customer_state
# Out:
# customer_state
# São Paulo            45070
# Rio de Janeiro       13981
# Minas Gerais         12509
# Rio Grande do Sul     5870
# Paraná                5390
# Santa Catarina        3869
# Bahia                 3696
# Distrito Federal      2290
# Goiás                 2191
# Espírito Santo        2185
# Name: count, dtype: int64

# %%
sns.barplot(y=Customer_state.index,x=Customer_state.values)
plt.title("Sales by Customer state")
# Out:
# Text(0.5, 1.0, 'Sales by Customer state')

# %%
top_categories=df['product_category_name'].value_counts()
top_categories=top_categories.head(10)

# %%
sns.barplot(x=top_categories.values,y=top_categories.index)
plt.title("Top 10 Most Bought Product Categories")
# Out:
# Text(0.5, 1.0, 'Top 10 Most Bought Product Categories')

# %%
year=df['order_purchase_timestamp'].dt.year
year=year.value_counts()

# %%
year
# Out:
# order_purchase_timestamp
# 2018    57784
# 2017    49069
# 2016      364
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df,x='product_volume',y='freight_value',alpha=.5)
plt.xlabel('Volume (cm³)')
plt.ylabel('Freight Value (R$)')
plt.grid(True)
plt.tight_layout()
plt.title('Product Volume vs Freight Value')
# Out:
# Text(0.5, 1.0, 'Product Volume vs Freight Value')

# %%
sns.scatterplot(data=df,x='price',y='freight_value',alpha=.3)
# Out:
# <Axes: xlabel='price', ylabel='freight_value'>
